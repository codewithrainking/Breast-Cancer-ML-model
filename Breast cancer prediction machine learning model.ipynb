# %% [markdown]
# # Loading Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # Reading the Data

# %%
test_data=pd.read_csv('dataR2.csv')

# %% [markdown]
# # Description

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    int64
# dtypes: float64(7), int64(3)
# memory usage: 9.2 KB

# %%
test_data.isnull().sum()
# Out:
# Age               0
# BMI               0
# Glucose           0
# Insulin           0
# HOMA              0
# Leptin            0
# Adiponectin       0
# Resistin          0
# MCP.1             0
# Classification    0
# dtype: int64

# %% [markdown]
# # Data Column Identification

# %%
test_data['Classification'].value_counts()
# Out:
# 2    64
# 1    52
# Name: Classification, dtype: int64

# %%
test_data.columns
# Out:
# Index(['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin',
#        'Resistin', 'MCP.1', 'Classification'],
#       dtype='object')

# %%
print(test_data.shape)
# Out:
# (116, 10)

# %% [markdown]
# #  Exploratory Data Analysis

# %%
test_data.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
test_data.describe()
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1  Classification
# count   116.000000  116.000000   116.000000      116.000000
# mean     10.180874   14.725966   534.647000        1.551724
# std       6.843341   12.390646   345.912663        0.499475
# min       1.656020    3.210000    45.843000        1.000000
# 25%       5.474283    6.881763   269.978250        1.000000
# 50%       8.352692   10.827740   471.322500        2.000000
# 75%      11.815970   17.755207   700.085000        2.000000
# max      38.040000   82.100000  1698.440000        2.000000

# %% [markdown]
# # Correlation Matrix

# %%
test_data.corr()
# Out:
#                      Age       BMI   Glucose   Insulin      HOMA    Leptin  \
# Age             1.000000  0.008530  0.230106  0.032495  0.127033  0.102626
# BMI             0.008530  1.000000  0.138845  0.145295  0.114480  0.569593
# Glucose         0.230106  0.138845  1.000000  0.504653  0.696212  0.305080
# Insulin         0.032495  0.145295  0.504653  1.000000  0.932198  0.301462
# HOMA            0.127033  0.114480  0.696212  0.932198  1.000000  0.327210
# Leptin          0.102626  0.569593  0.305080  0.301462  0.327210  1.000000
# Adiponectin    -0.219813 -0.302735 -0.122121 -0.031296 -0.056337 -0.095389
# Resistin        0.002742  0.195350  0.291327  0.146731  0.231101  0.256234
# MCP.1           0.013462  0.224038  0.264879  0.174356  0.259529  0.014009
# Classification -0.043555 -0.132586  0.384315  0.276804  0.284012 -0.001078
#
#                 Adiponectin  Resistin     MCP.1  Classification
# Age               -0.219813  0.002742  0.013462       -0.043555
# BMI               -0.302735  0.195350  0.224038       -0.132586
# Glucose           -0.122121  0.291327  0.264879        0.384315
# Insulin           -0.031296  0.146731  0.174356        0.276804
# HOMA              -0.056337  0.231101  0.259529        0.284012
# Leptin            -0.095389  0.256234  0.014009       -0.001078
# Adiponectin        1.000000 -0.252363 -0.200694       -0.019490
# Resistin          -0.252363  1.000000  0.366474        0.227310
# MCP.1             -0.200694  0.366474  1.000000        0.091381
# Classification    -0.019490  0.227310  0.091381        1.000000

# %% [markdown]
# # Graphical Approach using Automatic visualization

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# target='Classification'
df = AV.AutoViz(filename="",sep=',', depVar="Classification",dfte="dataR2.csv", header=0, verbose=1, 
                 lowess=False, chart_format='jpeg', max_rows_analyzed=150000, max_cols_analyzed=30)
# %matplotlib inline
# Out:
# Shape of your Data Set loaded: (116, 10)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  7
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     9 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Data Set Shape: 116 rows, 10 cols
# Data Set columns info:
# * Age: 0 nulls, 51 unique vals, most common: {45: 7, 66: 5}
# * BMI: 0 nulls, 110 unique vals, most common: {21.36752137: 2, 32.46191136: 2}
# * Glucose: 0 nulls, 50 unique vals, most common: {92: 9, 90: 6}
# * Insulin: 0 nulls, 113 unique vals, most common: {18.077: 2, 3.226: 2}
# * HOMA: 0 nulls, 116 unique vals, most common: {0.467408667: 1, 1.14478: 1}
# * Leptin: 0 nulls, 116 unique vals, most common: {8.8071: 1, 21.78: 1}
# * Adiponectin: 0 nulls, 115 unique vals, most common: {2.19428: 2, 9.7024: 1}
# * Resistin: 0 nulls, 116 unique vals, most common: {7.99585: 1, 4.82: 1}
# * MCP.1: 0 nulls, 113 unique vals, most common: {1698.44: 4, 417.114: 1}
# * Classification: 0 nulls, 2 unique vals, most common: {2: 64, 1: 52}
# --------------------------------------------------------------------
#    Columns to delete:
# '   []'
#    Boolean variables %s
# '   []'
#    Categorical variables %s
# "   ['Age', 'Glucose']"
#    Continuous variables %s
# "   ['BMI', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin', 'Resistin', 'MCP.1']"
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   Classification'
# Total Number of Scatter Plots = 28
# Could not draw Pivot Charts against Dependent Variable
# Time to run AutoViz = 17 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# # Splitting the Dataset

# %%
x=test_data.drop('Classification',axis=1)

# %%
y=test_data['Classification'].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=36)

# %% [markdown]
# # Fitting the model

# %%
treemodel= DecisionTreeClassifier()

# %%
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Confusion Matrix

# %% [markdown]
# # For Train Data

# %%
print('Confusion matrix - Train: ','\n',confusion_matrix(y_train,treemodel_predict))
# Out:
# Confusion matrix - Train:
#  [[39  0]
#  [ 0 42]]

# %% [markdown]
# # For  Test Data

# %%
print('Confusion matrix - Test: ','\n',confusion_matrix(y_test,treemodel_predict_h))
# Out:
# Confusion matrix - Test:
#  [[12  1]
#  [ 1 21]]

# %% [markdown]
# # Predicting Accuracy for Train Data

# %%
treemodel_predict=treemodel.predict(X_train)

# %%
accuracy=accuracy_score(y_train,treemodel_predict)

# %%
print("Training Accuracy:",accuracy)
# Out:
# Training Accuracy: 1.0

# %% [markdown]
# # Predicting Accuracy for Test Data

# %%
treemodel_predict_h=treemodel.predict(X_test)

# %%
treemodeld_accuracy=accuracy_score(y_test,treemodel_predict_h)

# %%
print("Testing Accuracy:",treemodeld_accuracy)
# Out:
# Testing Accuracy: 0.9428571428571428

# %% [markdown]
# # Recall,Precision,F1 score

# %% [markdown]
# # For Train Data

# %%
 print( classification_report(y_train, treemodel_predict))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        39
#            2       1.00      1.00      1.00        42
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81

# %% [markdown]
# # For Test Data

# %%
print(classification_report(y_test,treemodel_predict_h))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92        13
#            2       0.95      0.95      0.95        22
#
#     accuracy                           0.94        35
#    macro avg       0.94      0.94      0.94        35
# weighted avg       0.94      0.94      0.94        35
